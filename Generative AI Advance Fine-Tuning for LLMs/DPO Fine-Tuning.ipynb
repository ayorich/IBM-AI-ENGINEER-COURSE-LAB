# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Direct Preference Optimization (DPO) Using Hugging Face**

# %% [markdown]
# Estimated time needed: **60** minutes

# %% [markdown]
# Large language models (LLMs) have revolutionized the field of natural language processing (NLP) by achieving remarkable performance in various tasks. However, it is challenging to align these models with human preferences. Therefore, the direct preference optimization (DPO) method comes in place which directly optimizes LLMs based models on user preferences, enhancing their alignment with human expectations. In this hands-on lab, you'll use the transformer reinforcement learning (trl) library from Hugging Face to implement DPO and fine-tune LLMs.
#
# The objective of this lab is to provide a practical understanding of the DPO method and its implementation using the trl library.
#
# By the end of this lab, you'll have hands-on experience in creating a data set formatted for DPO, implementing the optimization process, and evaluating the enhanced performance of LLMs.

# %% [markdown]
# ## __Table of Contents__
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-required-libraries">Installing required libraries</a></li>
#             <li><a href="#Importing-required-libraries">Importing required libraries</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Create-and-configure-the-model-and-tokenizer">Create and configure the model and tokenizer</a>
#         <ol>
#             <li><a href="#Quantized-model-configuration-(Optional)">Quantized model configuration (Optional)</a></li>
#         </ol>
#     </li>
#     <li><a href="#Preprocess-dataset">Preprocess dataset</a></li>
#     <li><a href="#DPO-configuration">DPO configuration</a></li>
#     <li><a href="#DPO-training">DPO training</a></li>
#     <li><a href="#Exercise">Exercise</a>
# </ol>

# %% [markdown]
# ## Objectives
#
# After completing this lab, you'll be able to:
# - Understand the fundamentals of DPO and how it is different from proximal policy optimization (PPO)
# - Set up an environment by installing and configuring necessary tools and libraries, such as trl library from Hugging Face
# - Prepare a suitable environment for running DPO experiments with LLMs
# - Create a data set for DPO
# - Understand the required format for data sets used in DPO
# - Create and preprocess a data set that includes user preferences
# - Implement DPO by following a step-by-step guideline using the trl library
# - Set training arguments, create a base quantized LoRA model, and train it using a DPO trainer
# - Evaluate the performance of the LLM before and after applying DPO
# - Analyze the impact of DPO on aligning the model with user preferences
#
# By the end of this hands-on lab, you will be equipped with the knowledge and skills needed to apply DPO for fine-tuning LLMs using the trl library. This will enable you to enhance LLMs' performance and user alignment in various NLP applications.

# %% [markdown]
# ----

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Installing required libraries

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. You will need to run the following cell to install them.
#
# **Note:** In this lab, you don't have a pinned version to demonstrate the latest functionality, but you can always pin versions in your labs.

# %%
# %%time 
# %pip install --user trl==0.11.4 peft==0.14.0 matplotlib==3.9.0 pandas numpy==1.26.0 --user datasets==3.2.0 transformers==4.45.2
# %pip install torch==2.8.0  \
    --index-url https://download.pytorch.org/whl/cpu
# %pip install --user -qq rich==13.7.1
# Out:
# Collecting trl==0.11.4
#   Downloading trl-0.11.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: peft==0.14.0 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (0.14.0)
# Collecting matplotlib==3.9.0
#   Using cached matplotlib-3.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: pandas in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (2.2.2)
# Collecting numpy==1.26.0
#   Using cached numpy-1.26.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (99 kB)
# Requirement already satisfied: datasets==3.2.0 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (3.2.0)
# Collecting transformers==4.45.2
#   Using cached transformers-4.45.2-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: torch>=1.4.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from trl==0.11.4) (2.5.1)
# Requirement already satisfied: accelerate in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from trl==0.11.4) (0.34.0)
# Requirement already satisfied: tyro>=0.5.11 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from trl==0.11.4) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from peft==0.14.0) (24.2)
# Requirement already satisfied: psutil in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from peft==0.14.0) (7.0.0)
# Requirement already satisfied: pyyaml in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from peft==0.14.0) (6.0.2)
# Requirement already satisfied: tqdm in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from peft==0.14.0) (4.66.5)
# Requirement already satisfied: safetensors in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from peft==0.14.0) (0.7.0)
# Requirement already satisfied: huggingface-hub>=0.25.0 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from peft==0.14.0) (0.28.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib==3.9.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib==3.9.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib==3.9.0) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib==3.9.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib==3.9.0) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib==3.9.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from matplotlib==3.9.0) (2.9.0.post0)
# Requirement already satisfied: filelock in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from datasets==3.2.0) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from datasets==3.2.0) (22.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from datasets==3.2.0) (0.3.7)
# Collecting requests>=2.32.2 (from datasets==3.2.0)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: xxhash in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from datasets==3.2.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from datasets==3.2.0) (0.70.15)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets==3.2.0)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from datasets==3.2.0) (3.11.18)
# Requirement already satisfied: regex!=2019.12.17 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from transformers==4.45.2) (2024.11.6)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.45.2)
#   Downloading tokenizers-0.20.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from huggingface-hub>=0.25.0->peft==0.14.0) (4.13.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp->datasets==3.2.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp->datasets==3.2.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp->datasets==3.2.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp->datasets==3.2.0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp->datasets==3.2.0) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp->datasets==3.2.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from aiohttp->datasets==3.2.0) (1.20.0)
# Requirement already satisfied: idna>=2.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets==3.2.0) (3.4)
# Requirement already satisfied: six>=1.5 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib==3.9.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests>=2.32.2->datasets==3.2.0) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests>=2.32.2->datasets==3.2.0) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from requests>=2.32.2->datasets==3.2.0) (2022.12.7)
# Requirement already satisfied: networkx in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch>=1.4.0->trl==0.11.4) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch>=1.4.0->trl==0.11.4) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch>=1.4.0->trl==0.11.4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.4.0->trl==0.11.4) (1.3.0)
# Requirement already satisfied: docstring-parser>=0.15 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from tyro>=0.5.11->trl==0.11.4) (0.17.0)
# Requirement already satisfied: typeguard>=4.0.0 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from tyro>=0.5.11->trl==0.11.4) (4.4.4)
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub>=0.25.0->peft==0.14.0)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from jinja2->torch>=1.4.0->trl==0.11.4) (2.1.5)
# Downloading trl-0.11.4-py3-none-any.whl (316 kB)
# Using cached matplotlib-3.9.0-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
# Using cached numpy-1.26.0-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Downloading transformers-4.45.2-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 3.9 MB/s  0:00:02m0:00:0100:01
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Downloading tokenizers-0.20.3-cp311-cp311-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 4.7 MB/s  0:00:00 eta 0:00:01
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, requests, numpy, fsspec, tokenizers, matplotlib, transformers, trl
#   Attempting uninstall: matplotlib90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/8 [numpy]
#     Found existing installation: matplotlib 3.10.0━━━━━━━━━━━━ 2/8 [numpy]
#     Uninstalling matplotlib-3.10.0:0m╺━━━━━━━━━━━━━━ 5/8 [matplotlib]
#       Successfully uninstalled matplotlib-3.10.0━━━━━━━━━━━━━━ 5/8 [matplotlib]
#   Attempting uninstall: transformersm╺━━━━━━━━━━━━━━ 5/8 [matplotlib]
#     Found existing installation: transformers 4.43.4━━━━━━━━━━ 5/8 [matplotlib]
#     Uninstalling transformers-4.43.4:m╺━━━━━━━━━━━━━━ 5/8 [matplotlib]
#       Successfully uninstalled transformers-4.43.40m━━━━━━━━━ 6/8 [transformers]
#   Attempting uninstall: trl━━━━━━━━━━━╺━━━━━━━━━ 6/8 [transformers]
#     Found existing installation: trl 0.11.0╺━━━━━━━━━ 6/8 [transformers]
#     Uninstalling trl-0.11.0:━━━━━━╺━━━━━━━━━ 6/8 [transformers]
#       Successfully uninstalled trl-0.11.00m╺━━━━━━━━━ 6/8 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [trl]m6/8 [transformers]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# openai 1.79.0 requires httpx<1,>=0.23.0, but you have httpx 0.20.0 which is incompatible.
# langsmith 0.3.42 requires httpx<1,>=0.23.0, but you have httpx 0.20.0 which is incompatible.
# skillsnetwork 0.21.10 requires ipywidgets<=8.1.3, but you have ipywidgets 8.1.8 which is incompatible.
# Successfully installed fsspec-2024.9.0 matplotlib-3.9.0 numpy-1.26.0 requests-2.32.5 tokenizers-0.20.3 transformers-4.45.2 trl-0.11.4 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch==2.8.0
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.8.0-cp311-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.8.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from torch==2.8.0) (4.15.0)
# Collecting sympy>=1.13.3 (from torch==2.8.0)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.8.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from torch==2.8.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/ayodelekayode/.local/lib/python3.11/site-packages (from torch==2.8.0) (2024.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from sympy>=1.13.3->torch==2.8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages (from jinja2->torch==2.8.0) (2.1.5)
# Using cached https://download.pytorch.org/whl/cpu/torch-2.8.0-cp311-none-macosx_11_0_arm64.whl (73.5 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1━━━━━ 0/2 [sympy]
#   Attempting uninstall: torch━━━━━━━━━━━━━━━━━━━ 0/2 [sympy]
#     Found existing installation: torch 2.5.1 0/2 [sympy]
#     Uninstalling torch-2.5.1:╺━━━━━━━━━━━━━━━━━━━ 1/2 [torch]
#       Successfully uninstalled torch-2.5.1━━━━━━━━━━━━━━━━━━━ 1/2 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torch]32m1/2 [torch]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.20.1 requires torch==2.5.1, but you have torch 2.8.0 which is incompatible.
# torchaudio 2.3.0 requires torch==2.3.0, but you have torch 2.8.0 which is incompatible.
# Successfully installed sympy-1.14.0 torch-2.8.0
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# CPU times: user 235 ms, sys: 96 ms, total: 331 ms
# Wall time: 28.2 s

# %% [markdown]
# ### Importing required libraries
#
# _It's recommended to import all required libraries in one place (here):_

# %%
##imports
import multiprocessing
import os
import requests
import tarfile
import pandas as pd
import matplotlib.pyplot as plt

import torch
from datasets import load_dataset

from peft import LoraConfig
from transformers import AutoModelForCausalLM, AutoTokenizer,TrainingArguments, GPT2Tokenizer, set_seed, GenerationConfig
from trl import DPOConfig, DPOTrainer

# %% [markdown]
# ## Create and configure the model and tokenizer

# %%
# Load the GPT-2 model
model = AutoModelForCausalLM.from_pretrained("gpt2")

# Load a reference model 
model_ref = AutoModelForCausalLM.from_pretrained("gpt2")

# Load the GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Set the pad token to the end-of-sequence token
tokenizer.pad_token = tokenizer.eos_token
# Set the padding side to "right" to fix the overflow issue with FP16 training
tokenizer.padding_side = "right"

# Disable the use of the cache during the model's forward pass
model.config.use_cache = False

# %% [markdown]
# Here, you can check the model architecture.

# %%
model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2SdpaAttention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %% [markdown]
# ### Quantized model configuration (Optional)
# If you want memory-efficient training and have access to a GPU-powered environment, you can download the complete lab, uncomment the following two code blocks to create a quantized model and proceed with training the model on GPU. This is because you will need GPUs for the bits and bytes package.

# %%
#!pip install -U bitsandbytes # this package is required for quantization

# %% [markdown]
# **_Note:_**  _You can run the installed package by restarting a Kernel._

# %%
'''## Quantized model --only available on GPU
from transformers import BitsAndBytesConfig

# Configure the quantization parameters
quantization_config = BitsAndBytesConfig(
    # Load the model in 4-bit quantized format
    load_in_4bit=True,
    # Enable double quantization for better accuracy
    bnb_4bit_use_double_quant=True,
    # Use non-uniform 4-bit quantization (nf4)
    bnb_4bit_quant_type="nf4",
    # Use bfloat16 as the computation data type during quantization
    bnb_4bit_compute_dtype=torch.bfloat16
)

# Load GPT-2 model with the specified quantization configuration
model = AutoModelForCausalLM.from_pretrained("gpt2", quantization_config=quantization_config)

# Load a reference model with the same quantization configuration
model_ref = AutoModelForCausalLM.from_pretrained("gpt2", quantization_config=quantization_config)

# Load GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Set the pad token to the end-of-sequence token
tokenizer.pad_token = tokenizer.eos_token
# Set the padding side to "right" to fix the overflow issue with FP16 training
tokenizer.padding_side = "right"

# Disable the use of the cache during the model's forward pass
model.config.use_cache = False'''

# %% [markdown]
# ## Preprocess data set
#
# The "ultrafeedback_binarized" data set on Hugging Face is a collection of prompts and responses.

# %%
# Load the dataset from the specified location
ds = load_dataset("BarraHome/ultrafeedback_binarized")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train_prefs-00000-of-00001.parquet:   0%|          | 0.00/226M [00:00<?, ?B/s]
# test_prefs-00000-of-00001.parquet:   0%|          | 0.00/7.29M [00:00<?, ?B/s]
# test_sft-00000-of-00001.parquet:   0%|          | 0.00/3.72M [00:00<?, ?B/s]
# train_gen-00000-of-00001.parquet:   0%|          | 0.00/184M [00:00<?, ?B/s]
# test_gen-00000-of-00001.parquet:   0%|          | 0.00/3.02M [00:00<?, ?B/s]
# Generating train_prefs split:   0%|          | 0/61135 [00:00<?, ? examples/s]
# Generating train_sft split:   0%|          | 0/61135 [00:00<?, ? examples/s]
# Generating test_prefs split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/61135 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %% [markdown]
# This data set includes six splits.

# %%
ds.keys()
# Out:
# dict_keys(['train_prefs', 'train_sft', 'test_prefs', 'test_sft', 'train_gen', 'test_gen'])

# %% [markdown]
# Each record has different features among which you need to select from the three features, that is "chosen," "rejected," and "prompt." This means that for each prompt, a prefered response and a rejected response are provided.

# %%
ds["train_prefs"][0].keys()
# Out:
# dict_keys(['prompt', 'prompt_id', 'chosen', 'rejected', 'messages', 'score_chosen', 'score_rejected'])

# %% [markdown]
# You can check the sample record of data, where you can see three features along with other features that is the prompt, the rejected, and chosen responses.

# %%
ds["train_prefs"][0]
# Out:
# {'prompt': 'how can i develop a habit of drawing daily',
#  'prompt_id': '086b3e24f29b8956a01059f79c56db35d118a06fb6b844b095737d042795cd43',
#  'chosen': [{'content': 'how can i develop a habit of drawing daily',
#    'role': 'user'},
#   {'content': "Developing a daily habit of drawing can be challenging but with consistent practice and a few tips, it can become an enjoyable and rewarding part of your daily routine. Here are some strategies to help you develop the habit of drawing daily:\n\n1. Set a specific time: Allocate a specific time of the day to draw. It could be in the morning, afternoon, or evening. Make drawing a part of your daily routine.\n2. Set a specific duration: Determine the amount of time you want to spend on drawing each day. It can be as little as 10 minutes or as long as an hour. Be consistent with the duration to help build the habit.\n3. Start small and simple: Don't try to create a masterpiece every day, start with simple and easy-to-do sketches. Focus on improving your skills gradually.\n4. Use a variety of tools and mediums: Experiment with different tools like pencils, pens, markers, and different mediums like paper, canvas, or digital apps to keep your drawing practice interesting and engaging.\n5. Take breaks and rest: Taking breaks and resting after some time of drawing can help you avoid burnout and stay motivated.\n6. Challenge yourself: Set challenges like drawing objects from memory or a specific subject to improve your skills and keep your drawing practice interesting.\n7. Track your progress: Keep a record of your daily drawing practice and track your progress. This can be a source of motivation and help you see how far you've come.\n\nRemember, developing a habit takes time and patience. Stay consistent with your drawing practice, be flexible and open to trying new things, and with time, you'll develop a habit of daily drawing that brings you joy and satisfaction.",
#    'role': 'assistant'}],
#  'rejected': [{'content': 'how can i develop a habit of drawing daily',
#    'role': 'user'},
#   {'content': "One way to develop a habit of drawing daily is to allocate a specific time interval for drawing each day, whether it's early in the morning or before going to bed at night. You can also find inspiration or motivation to draw by joining drawing communities, following artists on social media, or going out into nature and sketching what you see. Additionally, practicing drawing every day can help you improve your skills over time.",
#    'role': 'assistant'}],
#  'messages': [{'content': 'how can i develop a habit of drawing daily',
#    'role': 'user'},
#   {'content': "Developing a daily habit of drawing can be challenging but with consistent practice and a few tips, it can become an enjoyable and rewarding part of your daily routine. Here are some strategies to help you develop the habit of drawing daily:\n\n1. Set a specific time: Allocate a specific time of the day to draw. It could be in the morning, afternoon, or evening. Make drawing a part of your daily routine.\n2. Set a specific duration: Determine the amount of time you want to spend on drawing each day. It can be as little as 10 minutes or as long as an hour. Be consistent with the duration to help build the habit.\n3. Start small and simple: Don't try to create a masterpiece every day, start with simple and easy-to-do sketches. Focus on improving your skills gradually.\n4. Use a variety of tools and mediums: Experiment with different tools like pencils, pens, markers, and different mediums like paper, canvas, or digital apps to keep your drawing practice interesting and engaging.\n5. Take breaks and rest: Taking breaks and resting after some time of drawing can help you avoid burnout and stay motivated.\n6. Challenge yourself: Set challenges like drawing objects from memory or a specific subject to improve your skills and keep your drawing practice interesting.\n7. Track your progress: Keep a record of your daily drawing practice and track your progress. This can be a source of motivation and help you see how far you've come.\n\nRemember, developing a habit takes time and patience. Stay consistent with your drawing practice, be flexible and open to trying new things, and with time, you'll develop a habit of daily drawing that brings you joy and satisfaction.",
#    'role': 'assistant'}],
#  'score_chosen': 8.5,
#  'score_rejected': 7.5}

# %% [markdown]
# Now, put the data set in the format that the DPO trainer accepts.
#
# | Chosen | Rejected | Prompt |
# | --- | --- | --- |
#  | Developing a daily habit of drawing can be challenging <br>but with consistent practice, and a few tips. | One way to develop a habit of drawing daily is <br>to allocate a specific time interval for drawing. | How can I develop a habit of drawing daily?|

# %%
# You can reduce the volume of data (due to resource limitations) by selecting the first 5% examples from each split of the dataset
for key in ds:
    #cnt = round(ds[key].__len__()*0.05)
    cnt=50
    ds[key] = ds[key].select(range(cnt))

# Define a function to process the data
def process(row):
    # delete unwanted columns
    del row["prompt_id"]
    del row["messages"]
    del row["score_chosen"]
    del row["score_rejected"]
    # retrieve the actual response text
    row["chosen"] = row["chosen"][-1]["content"]
    row["rejected"] = row["rejected"][-1]["content"]

    return row

# Apply the data processing function to the dataset
ds = ds.map(
    process,
    num_proc=multiprocessing.cpu_count(),
    load_from_cache_file=False,
)

# Split the dataset into training and evaluation sets
train_dataset = ds['train_prefs']
eval_dataset = ds['test_prefs']
# Out:
# Map (num_proc=12):   0%|          | 0/50 [00:00<?, ? examples/s]
# Map (num_proc=12):   0%|          | 0/50 [00:00<?, ? examples/s]
# Map (num_proc=12):   0%|          | 0/50 [00:00<?, ? examples/s]
# Map (num_proc=12):   0%|          | 0/50 [00:00<?, ? examples/s]
# Map (num_proc=12):   0%|          | 0/50 [00:00<?, ? examples/s]
# Map (num_proc=12):   0%|          | 0/50 [00:00<?, ? examples/s]

# %% [markdown]
# Let's check the data record.

# %%
train_dataset[0]
# Out:
# {'prompt': 'how can i develop a habit of drawing daily',
#  'chosen': "Developing a daily habit of drawing can be challenging but with consistent practice and a few tips, it can become an enjoyable and rewarding part of your daily routine. Here are some strategies to help you develop the habit of drawing daily:\n\n1. Set a specific time: Allocate a specific time of the day to draw. It could be in the morning, afternoon, or evening. Make drawing a part of your daily routine.\n2. Set a specific duration: Determine the amount of time you want to spend on drawing each day. It can be as little as 10 minutes or as long as an hour. Be consistent with the duration to help build the habit.\n3. Start small and simple: Don't try to create a masterpiece every day, start with simple and easy-to-do sketches. Focus on improving your skills gradually.\n4. Use a variety of tools and mediums: Experiment with different tools like pencils, pens, markers, and different mediums like paper, canvas, or digital apps to keep your drawing practice interesting and engaging.\n5. Take breaks and rest: Taking breaks and resting after some time of drawing can help you avoid burnout and stay motivated.\n6. Challenge yourself: Set challenges like drawing objects from memory or a specific subject to improve your skills and keep your drawing practice interesting.\n7. Track your progress: Keep a record of your daily drawing practice and track your progress. This can be a source of motivation and help you see how far you've come.\n\nRemember, developing a habit takes time and patience. Stay consistent with your drawing practice, be flexible and open to trying new things, and with time, you'll develop a habit of daily drawing that brings you joy and satisfaction.",
#  'rejected': "One way to develop a habit of drawing daily is to allocate a specific time interval for drawing each day, whether it's early in the morning or before going to bed at night. You can also find inspiration or motivation to draw by joining drawing communities, following artists on social media, or going out into nature and sketching what you see. Additionally, practicing drawing every day can help you improve your skills over time."}

# %% [markdown]
# Next, define LoRAConfig for efficient fine-tuning.

# %%
# PEFT (Parameter-Efficient Finetuning) configuration
peft_config = LoraConfig(
        # The rank of the low-rank adaptation weights
        r=4,
        # The target modules to apply the low-rank adaptation to
        target_modules=['c_proj','c_attn'],
        # The task type for the low-rank adaptation
        task_type="CAUSAL_LM",
        # The scaling factor for the low-rank adaptation weights
        lora_alpha=8,
        # The dropout probability for the low-rank adaptation weights
        lora_dropout=0.1,
        # The bias mode for the low-rank adaptation
        bias="none",
)

# %% [markdown]
# ### DPO configuration
#
# First, define training arguments.

# %%
# DPO configuration
from peft import get_peft_model
training_args = DPOConfig(
    # The beta parameter for the DPO loss function
    #beta is the temperature parameter for the DPO loss, typically something in the range of 0.1 to 0.5 . 
    beta=0.1,
    # The output directory for the training
    output_dir="dpo",
    # The number of training epochs
    num_train_epochs=5,
    # The batch size per device during training
    per_device_train_batch_size=1,
    # The batch size per device during evaluation
    per_device_eval_batch_size=1,
    # Whether to remove unused columns from the dataset
    remove_unused_columns=False,
    # The number of steps between logging training progress
    logging_steps=10,
    # The number of gradient accumulation steps
    gradient_accumulation_steps=1,
    # The learning rate for the optimization
    learning_rate=1e-4,
    # The evaluation strategy (e.g., after each step or epoch)
    evaluation_strategy="epoch",
    # The number of warmup steps for the learning rate scheduler
    warmup_steps=2,
    # Whether to use 16-bit (float16) precision
    fp16=False,
    # The number of steps between saving checkpoints
    save_steps=500,
    # The maximum number of checkpoints to keep
    #save_total_limit=2,
    # The reporting backend to use (set to 'none' to disable, you can also report to wandb or tensorboard)
    report_to='none'
)
# Out:
# /Users/ayodelekayode/.local/lib/python3.11/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %% [markdown]
# ### DPO training
#
# Next step is creating the actual trainer using DPOTrainer class.

# %%
tokenizer.pad_token = tokenizer.eos_token

# Create a DPO trainer
# This trainer will handle the fine-tuning of the model using the DPO technique
trainer = DPOTrainer(
        # The model to be fine-tuned
        model=model,
        # The reference model (not used in this case because LoRA has been used)
        ref_model=None,
        # The DPO training configuration
        args=training_args,
        # The beta parameter for the DPO loss function
       
        # The training dataset
        train_dataset=train_dataset,
        # The evaluation dataset
        eval_dataset=eval_dataset,
        # The tokenizer for the model
        tokenizer=tokenizer,
        # The PEFT (Parallel Efficient Finetuning) configuration
        peft_config=peft_config,
        # The maximum prompt length
        #max_prompt_length=512,
        # The maximum sequence length
        max_length=512,
    )
# Out:
# /Users/ayodelekayode/.local/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': max_length. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in DPOTrainer, please use the DPOConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /Users/ayodelekayode/.local/lib/python3.11/site-packages/peft/tuners/lora/layer.py:1264: UserWarning: fan_in_fan_out is set to False but the target module is `Conv1D`. Setting fan_in_fan_out to True.
#   warnings.warn(
# /Users/ayodelekayode/.local/lib/python3.11/site-packages/trl/trainer/dpo_trainer.py:655: UserWarning: You passed `max_length` to the DPOTrainer, the value you passed will override the one in the `DPOConfig`.
#   warnings.warn(
# /Users/ayodelekayode/.local/lib/python3.11/site-packages/trl/trainer/dpo_trainer.py:673: UserWarning: `max_prompt_length` is not set in the DPOConfig's init it will default to `128` by default, but you should do it yourself in the future.
#   warnings.warn(
# Tokenizing train dataset:   0%|          | 0/50 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1154 > 1024). Running this sequence through the model will result in indexing errors
# Tokenizing eval dataset:   0%|          | 0/50 [00:00<?, ? examples/s]

# %% [markdown]
# Please note that when using LoRA for the base model, it's efficient to leave the model_ref param null, in which case the DPOTrainer will unload the adapter for reference inference.
#
#
# Now, you're all set for training the model.

# %% [markdown]
# #### Training model

# %% [markdown]
# **Keep in mind that training the model on a CPU can be time-consuming and may cause the kernel to crash due to memory issues. If this happens, you can bypass training by loading the pre-trained model provided in the next section and proceed from there.**

# %%
# Start the training process
trainer.train()
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# {'loss': 0.528, 'grad_norm': 5.558926105499268, 'learning_rate': 9.677419354838711e-05, 'rewards/chosen': 0.18156273663043976, 'rewards/rejected': -0.20932495594024658, 'rewards/accuracies': 1.0, 'rewards/margins': 0.39088767766952515, 'logps/rejected': -526.9749755859375, 'logps/chosen': -569.7634887695312, 'logits/rejected': -101.87428283691406, 'logits/chosen': -105.9983139038086, 'epoch': 0.2}
# {'loss': 0.574, 'grad_norm': 3.6116697788238525, 'learning_rate': 9.274193548387096e-05, 'rewards/chosen': 0.2316473424434662, 'rewards/rejected': -0.0379846952855587, 'rewards/accuracies': 1.0, 'rewards/margins': 0.2696320414543152, 'logps/rejected': -403.8912658691406, 'logps/chosen': -527.6149291992188, 'logits/rejected': -103.69398498535156, 'logits/chosen': -106.24781799316406, 'epoch': 0.4}
# {'loss': 0.5562, 'grad_norm': 4.7407050132751465, 'learning_rate': 8.870967741935484e-05, 'rewards/chosen': 0.27108079195022583, 'rewards/rejected': -0.04549453407526016, 'rewards/accuracies': 1.0, 'rewards/margins': 0.3165753483772278, 'logps/rejected': -366.48321533203125, 'logps/chosen': -464.04736328125, 'logits/rejected': -107.1250991821289, 'logits/chosen': -107.26927185058594, 'epoch': 0.6}
# {'loss': 0.5673, 'grad_norm': 13.366474151611328, 'learning_rate': 8.467741935483871e-05, 'rewards/chosen': 0.4191164970397949, 'rewards/rejected': 0.11674152314662933, 'rewards/accuracies': 0.8999999761581421, 'rewards/margins': 0.3023749589920044, 'logps/rejected': -558.6124877929688, 'logps/chosen': -694.6488647460938, 'logits/rejected': -105.34855651855469, 'logits/chosen': -101.2337417602539, 'epoch': 0.8}
# {'loss': 0.5802, 'grad_norm': 8.512550354003906, 'learning_rate': 8.064516129032258e-05, 'rewards/chosen': 0.5713039636611938, 'rewards/rejected': 0.20236220955848694, 'rewards/accuracies': 0.800000011920929, 'rewards/margins': 0.3689417839050293, 'logps/rejected': -584.4554443359375, 'logps/chosen': -530.8161010742188, 'logits/rejected': -107.6309585571289, 'logits/chosen': -98.84693145751953, 'epoch': 1.0}
# {'eval_loss': 0.6504821181297302, 'eval_runtime': 11.3794, 'eval_samples_per_second': 4.394, 'eval_steps_per_second': 4.394, 'eval_rewards/chosen': 0.33396467566490173, 'eval_rewards/rejected': 0.18803218007087708, 'eval_rewards/accuracies': 0.5892857313156128, 'eval_rewards/margins': 0.14593246579170227, 'eval_logps/rejected': -512.7228393554688, 'eval_logps/chosen': -537.5150756835938, 'eval_logits/rejected': -103.37156677246094, 'eval_logits/chosen': -103.91834259033203, 'epoch': 1.0}
# {'loss': 0.35, 'grad_norm': 3.2167022228240967, 'learning_rate': 7.661290322580645e-05, 'rewards/chosen': 1.0687344074249268, 'rewards/rejected': 0.011821448802947998, 'rewards/accuracies': 1.0, 'rewards/margins': 1.056912899017334, 'logps/rejected': -554.7886962890625, 'logps/chosen': -660.323974609375, 'logits/rejected': -101.92127990722656, 'logits/chosen': -103.92735290527344, 'epoch': 1.2}
# {'loss': 0.3868, 'grad_norm': 2.1531529426574707, 'learning_rate': 7.258064516129033e-05, 'rewards/chosen': 1.4764776229858398, 'rewards/rejected': 0.2594483494758606, 'rewards/accuracies': 0.8999999761581421, 'rewards/margins': 1.217029333114624, 'logps/rejected': -487.70196533203125, 'logps/chosen': -668.1016845703125, 'logits/rejected': -100.95460510253906, 'logits/chosen': -97.20377349853516, 'epoch': 1.4}
# {'loss': 0.5173, 'grad_norm': 3.049673318862915, 'learning_rate': 6.854838709677419e-05, 'rewards/chosen': 1.172405481338501, 'rewards/rejected': 0.10207811743021011, 'rewards/accuracies': 0.800000011920929, 'rewards/margins': 1.0703275203704834, 'logps/rejected': -713.6286010742188, 'logps/chosen': -613.3321533203125, 'logits/rejected': -108.64671325683594, 'logits/chosen': -103.8944320678711, 'epoch': 1.6}
# {'loss': 0.5089, 'grad_norm': 16.10493278503418, 'learning_rate': 6.451612903225807e-05, 'rewards/chosen': 0.4659085273742676, 'rewards/rejected': -0.03290027752518654, 'rewards/accuracies': 0.8999999761581421, 'rewards/margins': 0.49880877137184143, 'logps/rejected': -224.33731079101562, 'logps/chosen': -345.29010009765625, 'logits/rejected': -107.40690612792969, 'logits/chosen': -106.96707916259766, 'epoch': 1.8}
# {'loss': 0.4956, 'grad_norm': 2.802854061126709, 'learning_rate': 6.048387096774194e-05, 'rewards/chosen': 0.8065248727798462, 'rewards/rejected': 0.17105916142463684, 'rewards/accuracies': 0.800000011920929, 'rewards/margins': 0.635465681552887, 'logps/rejected': -455.1087341308594, 'logps/chosen': -466.689453125, 'logits/rejected': -106.88126373291016, 'logits/chosen': -107.6635971069336, 'epoch': 2.0}
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'eval_loss': 0.6786603331565857, 'eval_runtime': 7.0132, 'eval_samples_per_second': 7.129, 'eval_steps_per_second': 7.129, 'eval_rewards/chosen': 0.6573352813720703, 'eval_rewards/rejected': 0.39248421788215637, 'eval_rewards/accuracies': 0.5799999833106995, 'eval_rewards/margins': 0.2648511230945587, 'eval_logps/rejected': -524.6696166992188, 'eval_logps/chosen': -530.8350219726562, 'eval_logits/rejected': -104.23941040039062, 'eval_logits/chosen': -104.34799194335938, 'epoch': 2.0}
# {'loss': 0.3059, 'grad_norm': 1.8596481084823608, 'learning_rate': 5.645161290322582e-05, 'rewards/chosen': 1.6100136041641235, 'rewards/rejected': -0.1209964007139206, 'rewards/accuracies': 1.0, 'rewards/margins': 1.73101007938385, 'logps/rejected': -270.865234375, 'logps/chosen': -438.808837890625, 'logits/rejected': -104.13609313964844, 'logits/chosen': -106.84855651855469, 'epoch': 2.2}
# {'loss': 0.2492, 'grad_norm': 1.9997214078903198, 'learning_rate': 5.241935483870968e-05, 'rewards/chosen': 1.9439446926116943, 'rewards/rejected': 0.13725456595420837, 'rewards/accuracies': 1.0, 'rewards/margins': 1.806689977645874, 'logps/rejected': -515.6527709960938, 'logps/chosen': -595.7627563476562, 'logits/rejected': -104.52577209472656, 'logits/chosen': -101.10981750488281, 'epoch': 2.4}
# {'loss': 0.5663, 'grad_norm': 2.5884346961975098, 'learning_rate': 4.8387096774193554e-05, 'rewards/chosen': 0.4941955506801605, 'rewards/rejected': -0.0344403050839901, 'rewards/accuracies': 0.699999988079071, 'rewards/margins': 0.5286358594894409, 'logps/rejected': -387.28570556640625, 'logps/chosen': -318.19635009765625, 'logits/rejected': -109.96197509765625, 'logits/chosen': -103.1555404663086, 'epoch': 2.6}
# {'loss': 0.4258, 'grad_norm': 3.4404242038726807, 'learning_rate': 4.435483870967742e-05, 'rewards/chosen': 1.134885549545288, 'rewards/rejected': 0.2035428285598755, 'rewards/accuracies': 0.800000011920929, 'rewards/margins': 0.9313427805900574, 'logps/rejected': -615.6527099609375, 'logps/chosen': -622.7401123046875, 'logits/rejected': -104.42356872558594, 'logits/chosen': -105.33272552490234, 'epoch': 2.8}
# {'loss': 0.1747, 'grad_norm': 3.39127516746521, 'learning_rate': 4.032258064516129e-05, 'rewards/chosen': 2.881207227706909, 'rewards/rejected': 0.03744415193796158, 'rewards/accuracies': 1.0, 'rewards/margins': 2.8437628746032715, 'logps/rejected': -648.9959716796875, 'logps/chosen': -747.4874267578125, 'logits/rejected': -104.7649917602539, 'logits/chosen': -105.07059478759766, 'epoch': 3.0}
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'eval_loss': 0.7049751877784729, 'eval_runtime': 6.9438, 'eval_samples_per_second': 7.201, 'eval_steps_per_second': 7.201, 'eval_rewards/chosen': 0.7994265556335449, 'eval_rewards/rejected': 0.4772014915943146, 'eval_rewards/accuracies': 0.5799999833106995, 'eval_rewards/margins': 0.32222506403923035, 'eval_logps/rejected': -523.8224487304688, 'eval_logps/chosen': -529.4140625, 'eval_logits/rejected': -104.70198059082031, 'eval_logits/chosen': -104.85867309570312, 'epoch': 3.0}
# {'loss': 0.2176, 'grad_norm': 3.587592840194702, 'learning_rate': 3.6290322580645165e-05, 'rewards/chosen': 1.537149429321289, 'rewards/rejected': -0.4625377058982849, 'rewards/accuracies': 1.0, 'rewards/margins': 1.9996871948242188, 'logps/rejected': -365.15838623046875, 'logps/chosen': -508.04583740234375, 'logits/rejected': -110.56257629394531, 'logits/chosen': -102.74098205566406, 'epoch': 3.2}
# {'loss': 0.2961, 'grad_norm': 1.2857987880706787, 'learning_rate': 3.2258064516129034e-05, 'rewards/chosen': 2.337024450302124, 'rewards/rejected': 0.11028479039669037, 'rewards/accuracies': 1.0, 'rewards/margins': 2.2267396450042725, 'logps/rejected': -438.6864318847656, 'logps/chosen': -485.79351806640625, 'logits/rejected': -108.61970520019531, 'logits/chosen': -109.52877044677734, 'epoch': 3.4}
# {'loss': 0.1733, 'grad_norm': 2.879058361053467, 'learning_rate': 2.822580645161291e-05, 'rewards/chosen': 2.4889369010925293, 'rewards/rejected': -0.22684288024902344, 'rewards/accuracies': 1.0, 'rewards/margins': 2.7157795429229736, 'logps/rejected': -513.566650390625, 'logps/chosen': -499.19781494140625, 'logits/rejected': -101.68096923828125, 'logits/chosen': -105.46797943115234, 'epoch': 3.6}
# {'loss': 0.2846, 'grad_norm': 1.0454051494598389, 'learning_rate': 2.4193548387096777e-05, 'rewards/chosen': 1.6556117534637451, 'rewards/rejected': -0.10244232416152954, 'rewards/accuracies': 0.800000011920929, 'rewards/margins': 1.7580540180206299, 'logps/rejected': -686.0791015625, 'logps/chosen': -647.5657958984375, 'logits/rejected': -104.02266693115234, 'logits/chosen': -102.57032775878906, 'epoch': 3.8}
# {'loss': 0.2802, 'grad_norm': 31.28993034362793, 'learning_rate': 2.0161290322580645e-05, 'rewards/chosen': 1.313232660293579, 'rewards/rejected': -0.4669114947319031, 'rewards/accuracies': 0.8999999761581421, 'rewards/margins': 1.7801440954208374, 'logps/rejected': -448.67431640625, 'logps/chosen': -569.7154541015625, 'logits/rejected': -104.82484436035156, 'logits/chosen': -102.93919372558594, 'epoch': 4.0}
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'eval_loss': 0.7194627523422241, 'eval_runtime': 6.9626, 'eval_samples_per_second': 7.181, 'eval_steps_per_second': 7.181, 'eval_rewards/chosen': 0.7931149005889893, 'eval_rewards/rejected': 0.4623875916004181, 'eval_rewards/accuracies': 0.6200000047683716, 'eval_rewards/margins': 0.3307272791862488, 'eval_logps/rejected': -523.9705200195312, 'eval_logps/chosen': -529.4772338867188, 'eval_logits/rejected': -104.96366119384766, 'eval_logits/chosen': -105.14867401123047, 'epoch': 4.0}
# {'loss': 0.1275, 'grad_norm': 3.2958638668060303, 'learning_rate': 1.6129032258064517e-05, 'rewards/chosen': 3.281663417816162, 'rewards/rejected': -0.11582450568675995, 'rewards/accuracies': 1.0, 'rewards/margins': 3.3974881172180176, 'logps/rejected': -472.1182556152344, 'logps/chosen': -588.1419067382812, 'logits/rejected': -105.19227600097656, 'logits/chosen': -106.4577865600586, 'epoch': 4.2}
# {'loss': 0.2423, 'grad_norm': 1.0569700002670288, 'learning_rate': 1.2096774193548388e-05, 'rewards/chosen': 1.5233796834945679, 'rewards/rejected': -0.47874659299850464, 'rewards/accuracies': 1.0, 'rewards/margins': 2.0021262168884277, 'logps/rejected': -378.95831298828125, 'logps/chosen': -444.3359375, 'logits/rejected': -106.5313720703125, 'logits/chosen': -104.13177490234375, 'epoch': 4.4}
# {'loss': 0.1813, 'grad_norm': 1.1126290559768677, 'learning_rate': 8.064516129032258e-06, 'rewards/chosen': 1.5782772302627563, 'rewards/rejected': -0.9397789239883423, 'rewards/accuracies': 0.8999999761581421, 'rewards/margins': 2.5180563926696777, 'logps/rejected': -555.3416748046875, 'logps/chosen': -576.1068115234375, 'logits/rejected': -101.4932861328125, 'logits/chosen': -101.53103637695312, 'epoch': 4.6}
# {'loss': 0.1829, 'grad_norm': 2.4272124767303467, 'learning_rate': 4.032258064516129e-06, 'rewards/chosen': 2.3072609901428223, 'rewards/rejected': -0.467092901468277, 'rewards/accuracies': 1.0, 'rewards/margins': 2.7743542194366455, 'logps/rejected': -538.1129150390625, 'logps/chosen': -558.4132080078125, 'logits/rejected': -101.29695129394531, 'logits/chosen': -104.3885726928711, 'epoch': 4.8}
# {'loss': 0.3269, 'grad_norm': 16.34366226196289, 'learning_rate': 0.0, 'rewards/chosen': 1.1065618991851807, 'rewards/rejected': -0.1719401627779007, 'rewards/accuracies': 0.8999999761581421, 'rewards/margins': 1.2785019874572754, 'logps/rejected': -517.8831787109375, 'logps/chosen': -538.6685791015625, 'logits/rejected': -116.60990142822266, 'logits/chosen': -108.02128601074219, 'epoch': 5.0}
# /Users/ayodelekayode/.pyenv/versions/3.11.7/lib/python3.11/site-packages/torch/utils/data/dataloader.py:684: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#   0%|          | 0/50 [00:00<?, ?it/s]
# {'eval_loss': 0.7263133525848389, 'eval_runtime': 6.98, 'eval_samples_per_second': 7.163, 'eval_steps_per_second': 7.163, 'eval_rewards/chosen': 0.7871826887130737, 'eval_rewards/rejected': 0.4510086178779602, 'eval_rewards/accuracies': 0.6200000047683716, 'eval_rewards/margins': 0.33617401123046875, 'eval_logps/rejected': -524.0843505859375, 'eval_logps/chosen': -529.5364990234375, 'eval_logits/rejected': -105.09727478027344, 'eval_logits/chosen': -105.28546905517578, 'epoch': 5.0}
# {'train_runtime': 99.9579, 'train_samples_per_second': 2.501, 'train_steps_per_second': 2.501, 'train_loss': 0.3639511399269104, 'epoch': 5.0}
# TrainOutput(global_step=250, training_loss=0.3639511399269104, metrics={'train_runtime': 99.9579, 'train_samples_per_second': 2.501, 'train_steps_per_second': 2.501, 'total_flos': 0.0, 'train_loss': 0.3639511399269104, 'epoch': 5.0})

# %%
# !python --v
# Out:
# unknown option --v
# usage: python [option] ... [-c cmd | -m mod | file | -] [arg] ...
# Try `python -h' for more information.

# %%
print(hasattr(model, "generate"))
# Out:
# True

# %% [markdown]
# Let's retrieve and plot the training loss versus evaluation loss.

# %%
# Retrieve log_history and save it to a dataframe
log = pd.DataFrame(trainer.state.log_history)
log_t = log[log['loss'].notna()]
log_e = log[log['eval_loss'].notna()]

# Plot train and evaluation losses
plt.plot(log_t["epoch"], log_t["loss"], label = "train_loss") 
plt.plot(log_e["epoch"], log_e["eval_loss"], label = "eval_loss") 
plt.legend() 
plt.show()

# %% [markdown]
# ![image](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/7KEnvtpUyNcJTINdArLf7A/loss%20dpo.png)

# %%
# Load the trained DPO model you just trained
dpo_model = AutoModelForCausalLM.from_pretrained('./dpo/checkpoint-250')

# %% [markdown]
# #### Loading trained model

# %% [markdown]
# If you encounter difficulty in running the training cell due to resource limitations, you can download the model to be fine-tuned:

# %%
# Define the URL and the filename
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/YIDeT3qihEpWChdXN_RmTg/DPO-tar.gz'
filename = './DPO.tar'

# Download the file
response = requests.get(url)

# Save the file locally
with open(filename, 'wb') as f:
    f.write(response.content)

# Extract the tar file
if tarfile.is_tarfile(filename):
    with tarfile.open(filename, 'r') as tar:
        tar.extractall()
        print("Files extracted:", tar.getnames())
else:
    print("The adownloaded file is not a tar file.")
# Out:
# Files extracted: ['DPO', 'DPO/adapter_config.json', 'DPO/tokenizer_config.json', 'DPO/merges.txt', 'DPO/adapter_model.safetensors', 'DPO/special_tokens_map.json', 'DPO/training_args.bin', 'DPO/README.md', 'DPO/vocab.json']

# %% [markdown]
# Then, load it into the model for further inference:

# %%
# Load the trained DPO model tiy just trained
dpo_model = AutoModelForCausalLM.from_pretrained('./DPO')

# %% [markdown]
# ### Generation

# %%
# Load the GPT-2 tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
# Set a seed for reproducibility
set_seed(42)


# Define the generation configuration for the DPO model
# This sets the parameters for text generation
generation_config = GenerationConfig(
        # Use sampling to generate diverse text
        do_sample=True,
        # Top-k sampling parameter
        top_k=1,
        # Temperature parameter to control the randomness of the generated text
        temperature=0.1,
        # Maximum number of new tokens to generate
        max_new_tokens=25,
        # Use the end-of-sequence token as the padding token
        pad_token_id=tokenizer.eos_token_id
    )

# Define the input prompt for text generation
PROMPT = "Is a higher octane gasoline better for your car?"
# Encode the prompt using the tokenizer
inputs = tokenizer(PROMPT, return_tensors='pt')

# Generate text using the DPO model
outputs = dpo_model.generate(**inputs, generation_config=generation_config)
# Decode the generated text and print it
print("DPO response:\t",tokenizer.decode(outputs[0], skip_special_tokens=True))

# Load the pre-trained GPT-2 model
gpt2_model = AutoModelForCausalLM.from_pretrained('gpt2')
# Generate text using the GPT-2 model
outputs = gpt2_model.generate(**inputs, generation_config=generation_config)
# Decode the generated text and print it
print("\nGPT2 response:\t",tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# DPO response:	 Is a higher octane gasoline better for your car?
#
# The answer is yes. The higher octane gasoline is better for your car.
#
# The higher octane gasoline
#
# GPT2 response:	 Is a higher octane gasoline better for your car?
#
# The answer is yes. The higher octane gasoline is more efficient and more fuel efficient.
#
# The higher oct

# %% [markdown]
# Althought the model is trained on a small data for 5 epochs only, it can be seen that the response generated by the DPO-tuned model is more concise and straightforward.

# %% [markdown]
# # Exercise

# %% [markdown]
# ### Exercise 1: Preprocess the `argilla/ultrafeedback-binarized-preferences-cleaned` Dataset

# %% [markdown]
# This data set comprises user-generated prompts along with corresponding responses categorized as either "chosen" or "rejected." It provides a rich source of binary feedback, making it ideal for training models to align with user preferences.

# %% [markdown]
# ##### Load the data set from the `argilla/ultrafeedback-binarized-preferences-cleaned`

# %%
#TODO
dataset = load_dataset("argilla/ultrafeedback-binarized-preferences-cleaned")

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# dataset = load_dataset("argilla/ultrafeedback-binarized-preferences-cleaned")
# ```
#
# </details>

# %%
dataset['train']

# %% [markdown]
# ##### Set the variable cnt to 50 and then select the first 50 (cnt) examples to reduce the volume of data for resource limitations.

# %%
#TODO
cnt = 50  # You can adjust this count based on your requirements

# Select the first 5% of examples
dataset['train'] = dataset['train'].select(range(cnt))

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# cnt = 50  # You can adjust this count based on your requirements
#
# # Select the first 5% of examples
# dataset['train'] = dataset['train'].select(range(cnt))
# ```
#
# </details>

# %% [markdown]
# ##### Create a function named `process` that takes a row of data as input. Within this function, remove unwanted columns such as `source, chosen-rating, chosen-model, rejected-rating, and rejected-model`. Then, use the map function to apply the process function to each row in the training data set.

# %%
#TODO

def process(row):
    # Delete unwanted columns
    del row["source"]
    del row["chosen-rating"]
    del row["chosen-model"]
    del row["rejected-rating"]
    del row["rejected-model"]
    
    # Retrieve the actual response text
    row["chosen"] = row["chosen"][-1]["content"]
    row["rejected"] = row["rejected"][-1]["content"]
    
    return row

# Apply the data processing function to the dataset
dataset['train'] = dataset['train'].map(
    process,
    num_proc=multiprocessing.cpu_count(),
    load_from_cache_file=False,
)

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# def process(row):
#     # Delete unwanted columns
#     del row["source"]
#     del row["chosen-rating"]
#     del row["chosen-model"]
#     del row["rejected-rating"]
#     del row["rejected-model"]
#
#     # Retrieve the actual response text
#     row["chosen"] = row["chosen"][-1]["content"]
#     row["rejected"] = row["rejected"][-1]["content"]
#
#     return row
#
# # Apply the data processing function to the dataset
# dataset['train'] = dataset['train'].map(
#     process,
#     num_proc=multiprocessing.cpu_count(),
#     load_from_cache_file=False,
# )
# ```
#
# </details>

# %% [markdown]
# ##### Split the data set into training and evaluation sets:
# Calculate the size for the training set as 80% of the total data. The remaining 20% will be used for evaluation.

# %%
#TODO
train_size = int(0.8 * len(dataset['train']))  # 80% for training
eval_size = len(dataset['train']) - train_size  # Remaining 20% for evaluation

train_dataset = dataset['train'].select(range(train_size))
eval_dataset = dataset['train'].select(range(train_size, train_size + eval_size))

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# train_size = int(0.8 * len(dataset['train']))  # 80% for training
# eval_size = len(dataset['train']) - train_size  # Remaining 20% for evaluation
#
# train_dataset = dataset['train'].select(range(train_size))
# eval_dataset = dataset['train'].select(range(train_size, train_size + eval_size))
# ```
#
# </details>

# %%
train_dataset

# %%
train_dataset[0]

# %% [markdown]
# ### Exercise 2: Prompt Inferencing and Comparison with GPT-2

# %%
PROMPT = input()

# %% [markdown]
# ##### Initialize the GPT-2 Tokenizer

# %%
#TODO
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# ```
#
# </details>

# %% [markdown]
# ##### Create a generation_config object to set the parameters for text generation.
# - do_sample=True    (It enables sampling, which allows for more diverse outputs.)
# - top_k=1 (It specifies the number of highest probability vocabulary tokens to consider during generation.)
# - temperature=0.1 (It controls the randomness of the output.)
# - max_new_tokens=25 (It sets the maximum number of new tokens to generate during inference.)
# - pad_token_id=tokenizer.eos_token_id (It specifies the token to use for padding.)

# %%
#TODO
generation_config = GenerationConfig(
    # Use sampling to generate diverse text
    do_sample=True,
    # Top-k sampling parameter: controls the number of highest probability tokens to consider
    top_k=1,
    # Temperature parameter: controls the randomness of the generated text
    temperature=0.1,
    # Maximum number of new tokens to generate
    max_new_tokens=25,
    # Use the end-of-sequence token as the padding token
    pad_token_id=tokenizer.eos_token_id
)

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# generation_config = GenerationConfig(
#     # Use sampling to generate diverse text
#     do_sample=True,
#     # Top-k sampling parameter: controls the number of highest probability tokens to consider
#     top_k=1,
#     # Temperature parameter: controls the randomness of the generated text
#     temperature=0.1,
#     # Maximum number of new tokens to generate
#     max_new_tokens=25,
#     # Use the end-of-sequence token as the padding token
#     pad_token_id=tokenizer.eos_token_id
# )
# ```
#
# </details>

# %% [markdown]
# ##### Create a function named `generate_dpo_response` that takes a prompt as input and generates a response using the DPO model (`dpo_model`).

# %%
#TODO
def generate_dpo_response(prompt):
    # Tokenize the prompt
    inputs = tokenizer(prompt, return_tensors='pt')

    # Generate text using the DPO model
    outputs = dpo_model.generate(**inputs, generation_config=generation_config)
    
    # Decode and return the response
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# def generate_dpo_response(prompt):
#     # Tokenize the prompt
#     inputs = tokenizer(prompt, return_tensors='pt')
#
#     # Generate text using the DPO model
#     outputs = dpo_model.generate(**inputs, generation_config=generation_config)
#
#     # Decode and return the response
#     return tokenizer.decode(outputs[0], skip_special_tokens=True)
# ```
#
# </details>

# %% [markdown]
# ##### Create another function named `generate_gpt2_response` that takes a prompt as input and generates a response using the GPT-2 model (`gpt2_model`).

# %%
#TODO
def generate_gpt2_response(prompt):
    # Tokenize the prompt
    inputs = tokenizer(prompt, return_tensors='pt')

    # Generate text using the GPT-2 model
    outputs = gpt2_model.generate(**inputs, generation_config=generation_config)
    
    # Decode and return the response
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# def generate_gpt2_response(prompt):
#     # Tokenize the prompt
#     inputs = tokenizer(prompt, return_tensors='pt')
#
#     # Generate text using the GPT-2 model
#     outputs = gpt2_model.generate(**inputs, generation_config=generation_config)
#
#     # Decode and return the response
#     return tokenizer.decode(outputs[0], skip_special_tokens=True)
# ```
#
# </details>

# %% [markdown]
# ##### Call both functions with a prompt and compare the responses.

# %%
#TODO
dpo_response = generate_dpo_response(PROMPT)
gpt2_response = generate_gpt2_response(PROMPT)

# Print the responses
print("DPO response:\t", dpo_response)
print("\nGPT-2 response:\t", gpt2_response)

# %% [markdown]
# <details>
#     <summary>Click here for hint</summary>
#
# ```python
# # Generate responses
# dpo_response = generate_dpo_response(PROMPT)
# gpt2_response = generate_gpt2_response(PROMPT)
#
# # Print the responses
# print("DPO response:\t", dpo_response)
# print("\nGPT-2 response:\t", gpt2_response)
# ```
#
# </details>

# %% [markdown]
# # Congratulations! You have completed the lab!

# %% [markdown]
# ## Authors

# %% [markdown]
# [Fateme Akbari](https://www.linkedin.com/in/fatemeakbari/) is a Ph.D. candidate in Information Systems at McMaster University with demonstrated research experience in Machine Learning and NLP.
#
# [Kunal Makwana](https://author.skills.network/instructors/kunal_makwana) is a Data Scientist at IBM and is currently pursuing his Master's in Computer Science at Dalhousie University.

# %% [markdown]
# ## References
# [DPO Trainer](https://huggingface.co/docs/trl/main/en/dpo_trainer)

# %% [markdown]
# © Copyright IBM Corporation. All rights reserved.
